# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_style("whitegrid")
sns.set_palette("colorblind")
palette = sns.color_palette()
figsize = (15,8)
legend_fontsize = 16

from matplotlib import rc
rc('font',**{'family':'sans-serif'})
rc('text', usetex=True)
rc('text.latex',preamble=r'\usepackage[utf8]{inputenc}')
rc('text.latex',preamble=r'\usepackage[russian]{babel}')
rc('figure', **{'dpi': 300})
import numpy as np

# %%
df = pd.read_csv("build/out.csv", header=None)

# %%
df
# Out:
#          0
# 0     1508
# 1     1499
# 2     1510
# 3     1515
# 4     1518
# ...    ...
# 2301   546
# 2302   547
# 2303   556
# 2304   559
# 2305   560
#
# [2306 rows x 1 columns]

# %%
plt.plot(df[0][12000: 48000])
#plt.stem(df[0][:15000], markerfmt=" ")
#plt.xlabel("М")
#plt.ylabel("Значение сигнала")
#plt.title("Мнимая часть")
plt.show()

# %%
import numpy, pylab
data = numpy.memmap("signal.pcm", dtype='h', mode='r')
pylab.plot(data[12000: 48000])
pylab.show()
