# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_style("whitegrid")
sns.set_palette("colorblind")
palette = sns.color_palette()
figsize = (15,8)
legend_fontsize = 16

from matplotlib import rc
rc('font',**{'family':'sans-serif'})
rc('text', usetex=True)
rc('text.latex',preamble=r'\usepackage[utf8]{inputenc}')
rc('text.latex',preamble=r'\usepackage[russian]{babel}')
rc('figure', **{'dpi': 300})

# %%
df = pd.read_csv("out.txt", header=None)

# %% [markdown]
# # Генератор

# %%
plt.plot(df[0])
plt.xlabel("номер отсчёта")
plt.ylabel("Значение сигнала")
plt.title("Мнимая часть")
plt.show()

# %%
plt.plot(df[1])
plt.xlabel("номер отсчёта")
plt.ylabel("Значение сигнала")
plt.title("Реальная часть")
plt.show()

# %%
df = pd.read_csv("out2.txt", header=None)

# %%
df.head()
# Out:
#               0             1  2
# 0  0.000000e+00  1.000000e+00  0
# 1 -1.000000e+00 -1.836970e-16  1
# 2 -2.449290e-16  1.000000e+00  1
# 3  1.000000e+00  3.061620e-16  1
# 4 -2.449290e-16  1.000000e+00  0

# %%
plt.plot(df[0])
plt.xlabel("номер отсчёта")
plt.ylabel("Значение сигнала")
plt.title("Мнимая часть")
plt.show()

# %%
plt.plot(df[1])
plt.xlabel("номер отсчёта")
plt.ylabel("Значение сигнала")
plt.title("Реальная часть")
plt.show()

# %%
plt.plot(df[2])
plt.xlabel("номер отсчёта")
plt.ylabel("Полезная нагрузка")
plt.title("Значение")
plt.show()
